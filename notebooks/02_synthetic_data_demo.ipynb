# %% [markdown]
# # Synthetic Data Generation Demo
#
# This notebook demonstrates the synthetic code-mixed data generation process.
# It shows how monolingual sentences are transformed into code-mixed examples by replacing 20-40% of content words.
