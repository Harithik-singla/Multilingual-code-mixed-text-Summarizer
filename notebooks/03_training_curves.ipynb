# %% [markdown]
# # Training Curves Analysis
#
# This notebook visualizes and analyzes training curves across all three phases.
# It plots loss, metrics, and performance improvements over training epochs.
